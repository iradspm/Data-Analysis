# %%
import pandas as pd

# %%
df=pd.read_excel("DI_kenya.xls")
df.head()
# Out:
#   Serial          Event  &quot;Code County&quot; &quot;County&quot;  \
# 0  30618  ROAD ACCIDENT                     30.0            NAIROBI
# 1  30617  ROAD ACCIDENT                     13.0             KIAMBU
# 2  30614  ROAD ACCIDENT                     45.0             VIHIGA
# 3  30613           FIRE                     31.0             NAKURU
# 4  30612  ROAD ACCIDENT                     36.0              NYERI
#
#    &quot;Code Level 1&quot;  &quot;Level 1&quot;  &quot;Code Level 2&quot;  \
# 0                       NaN                  NaN                       NaN
# 1                       NaN                  NaN                       NaN
# 2                       NaN                  NaN                       NaN
# 3                       NaN                  NaN                       NaN
# 4                       NaN                  NaN                       NaN
#
#    &quot;Level 2&quot;                 &quot;Location&quot; Date (YMD)  ...  \
# ...

# %%
df
# Out:
#      Serial          Event  &quot;Code County&quot; &quot;County&quot;  \
# 0     30618  ROAD ACCIDENT                     30.0            NAIROBI
# 1     30617  ROAD ACCIDENT                     13.0             KIAMBU
# 2     30614  ROAD ACCIDENT                     45.0             VIHIGA
# 3     30613           FIRE                     31.0             NAKURU
# 4     30612  ROAD ACCIDENT                     36.0              NYERI
# ...     ...            ...                      ...                ...
# 8543   7060          FLOOD                     45.0             VIHIGA
# 8544   7059          FLOOD                     23.0            MAKUENI
# 8545   7058          FLOOD                     22.0           MACHAKOS
# 8546   7057          FLOOD                     22.0           MACHAKOS
# 8547   7056          FLOOD                     22.0           MACHAKOS
#
#       &quot;Code Level 1&quot;  &quot;Level 1&quot;  &quot;Code Level 2&quot;  \
# ...

# %%
df.columns
# Out:
# Index(['Serial', 'Event', '&quot;Code County&quot;', '&quot;County&quot;',
#        '&quot;Code Level 1&quot;', '&quot;Level 1&quot;',
#        '&quot;Code Level 2&quot;', '&quot;Level 2&quot;',
#        '&quot;Location&quot;', 'Date (YMD)', 'Comments', 'Cause',
#        'Description of Cause', 'Source', 'Magnitude', 'GLIDEnumber',
#        'Other sectors', 'DataCards', 'Deaths', 'Injured', 'Missing',
#        'Houses Destroyed', 'Houses Damaged', 'Directly affected',
#        'Indirectly Affected', 'Relocated', 'Evacuated', 'Losses $USD',
#        'Losses $Local', 'Education centers', 'Hospitals',
#        'Damages in crops Ha.'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Serial                         0
# Event                          0
# &quot;Code County&quot;       15
# &quot;County&quot;            15
# &quot;Code Level 1&quot;    8548
# &quot;Level 1&quot;         8548
# &quot;Code Level 2&quot;    8548
# &quot;Level 2&quot;         8548
# &quot;Location&quot;         395
# Date (YMD)                     0
# Comments                    1853
# Cause                         70
# Description of Cause         516
# Source                       169
# Magnitude                   8548
# GLIDEnumber                 8351
# Other sectors               8323
# DataCards                      0
# Deaths                      2921
# Injured                     6913
# Missing                     8494
# Houses Destroyed            8181
# Houses Damaged              8423
# Directly affected           8474
# Indirectly Affected         7963
# Relocated                   8531
# Evacuated                   8534
# Losses $USD                 8524
# ...

# %%
df1=df[['Event','&quot;Code County&quot;','&quot;County&quot;','Date (YMD)', 'Comments', 'Cause',
       'Description of Cause', 'Source', 'Magnitude', 'GLIDEnumber',
       'Other sectors', 'DataCards', 'Deaths']]
df1
# Out:
#               Event  &quot;Code County&quot; &quot;County&quot; Date (YMD)  \
# 0     ROAD ACCIDENT                     30.0            NAIROBI  2022/7/20
# 1     ROAD ACCIDENT                     13.0             KIAMBU  2022/7/21
# 2     ROAD ACCIDENT                     45.0             VIHIGA  2022/7/21
# 3              FIRE                     31.0             NAKURU  2022/7/21
# 4     ROAD ACCIDENT                     36.0              NYERI  2022/7/19
# ...             ...                      ...                ...        ...
# 8543          FLOOD                     45.0             VIHIGA  2013/4/13
# 8544          FLOOD                     23.0            MAKUENI  2013/4/11
# 8545          FLOOD                     22.0           MACHAKOS  2013/4/13
# 8546          FLOOD                     22.0           MACHAKOS  2013/4/11
# 8547          FLOOD                     22.0           MACHAKOS  2013/4/13
#
# ...

# %%
ev=df['Event'].value_counts()
ev
# Out:
# ROAD ACCIDENT          4054
# DROWNING               1152
# FIRE                   1149
# FLOOD                   742
# DROUGHT                 574
# EPIDEMIC                302
# ELECTROCUTION           149
# WINDSTORM               107
# LANDSLIDE                63
# RAINS                    48
# ANIMAL INCIDENT          46
# FOREST FIRE              41
# STRUCTURAL COLLAPSE      34
# CONFLICT                 21
# THUNDERSTORM             20
# LIGHTNING                17
# MUDSLIDE                 13
# TERROR ATTACK             9
# SUBSIDENCE                3
# STORM                     2
# PLAGUE                    1
# AIRCRAFT CRASH            1
# Name: Event, dtype: int64

# %%
ev.head(10)
# Out:
# ROAD ACCIDENT    4054
# DROWNING         1152
# FIRE             1149
# FLOOD             742
# DROUGHT           574
# EPIDEMIC          302
# ELECTROCUTION     149
# WINDSTORM         107
# LANDSLIDE          63
# RAINS              48
# Name: Event, dtype: int64

# %%
df1.head()
# Out:
#            Event  &quot;Code County&quot; &quot;County&quot; Date (YMD)  \
# 0  ROAD ACCIDENT                     30.0            NAIROBI  2022/7/20
# 1  ROAD ACCIDENT                     13.0             KIAMBU  2022/7/21
# 2  ROAD ACCIDENT                     45.0             VIHIGA  2022/7/21
# 3           FIRE                     31.0             NAKURU  2022/7/21
# 4  ROAD ACCIDENT                     36.0              NYERI  2022/7/19
#
#                            Comments         Cause  \
# 0  CASE PENDING UNDER INVESTIGATION  H. Behaviour
# 1  CASE PENDING UNDER INVESTIGATION  H. Behaviour
# 2  CASE PENDING UNDER INVESTIGATION  H. Behaviour
# 3  CASE PENDING UNDER INVISTIGATION   Other cause
# 4  CASE PENDING UNDER INVESTIGATION  H. Behaviour
#
#             Description of Cause         Source  Magnitude GLIDEnumber  \
# 0  M/v hit a crossing pedestrian  police report        NaN         NaN
# 1  M/v hit a crossing pedestrian  police report        NaN         NaN
# ...

# %%
acc=df1.groupby('Event')['Deaths'].sum()
acc.sort_values(ascending=False)
# Out:
# Event
# ROAD ACCIDENT          4723.0
# FIRE                   1902.0
# DROWNING               1251.0
# FLOOD                   565.0
# EPIDEMIC                444.0
# ELECTROCUTION           155.0
# LANDSLIDE               122.0
# WINDSTORM                85.0
# STRUCTURAL COLLAPSE      68.0
# ANIMAL INCIDENT          36.0
# THUNDERSTORM             24.0
# LIGHTNING                20.0
# TERROR ATTACK            13.0
# MUDSLIDE                 12.0
# RAINS                    10.0
# CONFLICT                  6.0
# STORM                     5.0
# DROUGHT                   5.0
# SUBSIDENCE                1.0
# PLAGUE                    0.0
# FOREST FIRE               0.0
# AIRCRAFT CRASH            0.0
# Name: Deaths, dtype: float64

# %%
p1=df1.groupby(['Event','&quot;County&quot;'])['Deaths'].sum()
p1.sort_values(ascending=False)
# Out:
# Event           &quot;County&quot;
# FIRE            KIAMBU                1521.0
# ROAD ACCIDENT   NAIROBI                835.0
#                 NAKURU                 348.0
#                 KIAMBU                 305.0
#                 MACHAKOS               261.0
#                                        ...
# FLOOD           NANDI                    0.0
#                 LAMU                     0.0
# FIRE            WEST POKOT               0.0
#                 WAJIR                    0.0
# AIRCRAFT CRASH  LAIKIPIA                 0.0
# Name: Deaths, Length: 500, dtype: float64

# %%
cause=df1.groupby(['Event','Description of Cause'])['Deaths'].sum()
cause
# Out:
# Event            Description of Cause
# AIRCRAFT CRASH   Helicopter crashed                                           0.0
# ANIMAL INCIDENT  41 goats raided                                              1.0
#                  A crocodile attacked a juvenile while being bathed           0.0
#                  A leopard attacked a person                                  0.0
#                  A man attacked by hippo on his way to the beach to fish      0.0
#                                                                              ...
# WINDSTORM        slipped and drowned                                          1.0
#                  strong winds that destroyed roof of a government building    0.0
#                  two m/vehicles collided head on                              1.0
#                  unknown                                                      0.0
#                  was found floating                                           1.0
# ...

# %%
df1['desc']=df1['Description of Cause'].str.lower()
# Out:
# <ipython-input-50-5947d897a8f4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['desc']=df1['Description of Cause'].str.lower()

# %%
df1
# Out:
#               Event  &quot;Code County&quot; &quot;County&quot; Date (YMD)  \
# 0     ROAD ACCIDENT                     30.0            NAIROBI  2022/7/20
# 1     ROAD ACCIDENT                     13.0             KIAMBU  2022/7/21
# 2     ROAD ACCIDENT                     45.0             VIHIGA  2022/7/21
# 3              FIRE                     31.0             NAKURU  2022/7/21
# 4     ROAD ACCIDENT                     36.0              NYERI  2022/7/19
# ...             ...                      ...                ...        ...
# 8543          FLOOD                     45.0             VIHIGA  2013/4/13
# 8544          FLOOD                     23.0            MAKUENI  2013/4/11
# 8545          FLOOD                     22.0           MACHAKOS  2013/4/13
# 8546          FLOOD                     22.0           MACHAKOS  2013/4/11
# 8547          FLOOD                     22.0           MACHAKOS  2013/4/13
#
# ...

# %%
c=df1[df1['Event']=='ROAD ACCIDENT']
c
# Out:
#               Event  &quot;Code County&quot; &quot;County&quot; Date (YMD)  \
# 0     ROAD ACCIDENT                     30.0            NAIROBI  2022/7/20
# 1     ROAD ACCIDENT                     13.0             KIAMBU  2022/7/21
# 2     ROAD ACCIDENT                     45.0             VIHIGA  2022/7/21
# 4     ROAD ACCIDENT                     36.0              NYERI  2022/7/19
# 6     ROAD ACCIDENT                     12.0            KERICHO  2022/7/20
# ...             ...                      ...                ...        ...
# 8511  ROAD ACCIDENT                     26.0               MERU  2015/5/26
# 8512  ROAD ACCIDENT                     13.0             KIAMBU  2015/5/27
# 8513  ROAD ACCIDENT                     15.0          KIRINYAGA  2015/5/24
# 8514  ROAD ACCIDENT                     13.0             KIAMBU  2015/5/23
# 8515  ROAD ACCIDENT                     16.0              KISII  2015/5/14
#
# ...

# %%
d=c.groupby(['desc'])['Deaths'].sum()
d.sort_values(ascending=False)
# Out:
# desc
# lost control                                      369.0
# careless driving                                  249.0
# hit                                               233.0
# head on collision                                 189.0
# case pending under investigation                  102.0
#                                                   ...
# a matatu knocked down a pedestrian                  0.0
# motor vehicle hit a heard of goats and sheep        0.0
# a m/cycle hit the m/vehicle                         0.0
# m/v lost control and collided with another m/v      0.0
# care                                                0.0
# Name: Deaths, Length: 1375, dtype: float64

# %%
behav=c.groupby(['Event','Cause'])['Deaths'].sum()
behav
# Out:
# Event          Cause
# ROAD ACCIDENT  Drowning           7.0
#                Error             15.0
#                Flood             15.0
#                H. Behaviour    4510.0
#                Landslide          5.0
#                Other cause      123.0
#                Unknown           23.0
#                Windstorm          2.0
# Name: Deaths, dtype: float64

# %%
df1
# Out:
#               Event  &quot;Code County&quot; &quot;County&quot; Date (YMD)  \
# 0     ROAD ACCIDENT                     30.0            NAIROBI  2022/7/20
# 1     ROAD ACCIDENT                     13.0             KIAMBU  2022/7/21
# 2     ROAD ACCIDENT                     45.0             VIHIGA  2022/7/21
# 3              FIRE                     31.0             NAKURU  2022/7/21
# 4     ROAD ACCIDENT                     36.0              NYERI  2022/7/19
# ...             ...                      ...                ...        ...
# 8543          FLOOD                     45.0             VIHIGA  2013/4/13
# 8544          FLOOD                     23.0            MAKUENI  2013/4/11
# 8545          FLOOD                     22.0           MACHAKOS  2013/4/13
# 8546          FLOOD                     22.0           MACHAKOS  2013/4/11
# 8547          FLOOD                     22.0           MACHAKOS  2013/4/13
#
# ...

# %%
df1['years']=df1['Date (YMD)'].apply(lambda x:str(x).split('/')[0])
# Out:
# <ipython-input-74-78d873ab9188>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['years']=df1['Date (YMD)'].apply(lambda x:str(x).split('/')[0])

# %%
df1.head()
# Out:
#            Event  &quot;Code County&quot; &quot;County&quot; Date (YMD)  \
# 0  ROAD ACCIDENT                     30.0            NAIROBI  2022/7/20
# 1  ROAD ACCIDENT                     13.0             KIAMBU  2022/7/21
# 2  ROAD ACCIDENT                     45.0             VIHIGA  2022/7/21
# 3           FIRE                     31.0             NAKURU  2022/7/21
# 4  ROAD ACCIDENT                     36.0              NYERI  2022/7/19
#
#                            Comments         Cause  \
# 0  CASE PENDING UNDER INVESTIGATION  H. Behaviour
# 1  CASE PENDING UNDER INVESTIGATION  H. Behaviour
# 2  CASE PENDING UNDER INVESTIGATION  H. Behaviour
# 3  CASE PENDING UNDER INVISTIGATION   Other cause
# 4  CASE PENDING UNDER INVESTIGATION  H. Behaviour
#
#             Description of Cause         Source  Magnitude GLIDEnumber  \
# 0  M/v hit a crossing pedestrian  police report        NaN         NaN
# 1  M/v hit a crossing pedestrian  police report        NaN         NaN
# ...

# %%
disaster_years=df1['years'].value_counts()
disaster_years.sort_values(ascending=False)
# Out:
# 2020    1976
# 2021    1703
# 2022    1234
# 2019     851
# 2015     548
# 2016     525
# 2009     430
# 2010     301
# 2011     277
# 2014     221
# 2012     137
# 2013     120
# 2008      90
# 2002      32
# 2005      29
# 2007      23
# 2006      21
# 2017      15
# 2003       9
# 1997       4
# 2004       2
# Name: years, dtype: int64

# %%
plt.figure(figsize =(15,7))
sns.countplot(x='years',data=df1)
plt.show()
